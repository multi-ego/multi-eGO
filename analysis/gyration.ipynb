# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


amber_gyr_pairs = pd.read_csv('native_TTR/gyrate_amber.txt', sep = '\\s+', header=None)
amber_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
amber_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
amber_gyr_pairs['time'] = amber_gyr_pairs['time']/1000

smogtogromos_gyr_pairs = pd.read_csv('native_TTR/gyrate_smogtogromos.txt', sep = '\\s+', header=None)
smogtogromos_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
smogtogromos_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
smogtogromos_gyr_pairs['time'] = smogtogromos_gyr_pairs['time']/1000
#
#greta_ljr01_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_ljr01.txt', sep = '\\s+', header=None)
#greta_ljr01_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
#greta_ljr01_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
#greta_ljr01_gyr_pairs['time'] = greta_ljr01_gyr_pairs['time']/1000
#
#greta_ljr012_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_ljr012.txt', sep = '\\s+', header=None)
#greta_ljr012_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
#greta_ljr012_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
#greta_ljr012_gyr_pairs['time'] = greta_ljr012_gyr_pairs['time']/1000
#
#greta_ljr015_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_ljr015.txt', sep = '\\s+', header=None)
#greta_ljr015_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
#greta_ljr015_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
#greta_ljr015_gyr_pairs['time'] = greta_ljr015_gyr_pairs['time']/1000
#
#greta_newljr_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_newljr.txt', sep = '\\s+', header=None)
#greta_newljr_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
#greta_newljr_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
#greta_newljr_gyr_pairs['time'] = greta_newljr_gyr_pairs['time']/1000
#
greta_newdi_harp0_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_newljr_newdi_harp0.txt', sep = '\\s+', header=None)
greta_newdi_harp0_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta_newdi_harp0_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta_newdi_harp0_gyr_pairs['time'] = greta_newdi_harp0_gyr_pairs['time']/1000
#
#
#greta_newdi_harp20_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_newljr_newdi_harp20.txt', sep = '\\s+', header=None)
#greta_newdi_harp20_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
#greta_newdi_harp20_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
#greta_newdi_harp20_gyr_pairs['time'] = greta_newdi_harp20_gyr_pairs['time']/1000

greta_latestdihedrals_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_latestdihedrals.txt', sep = '\\s+', header=None)
greta_latestdihedrals_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta_latestdihedrals_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta_latestdihedrals_gyr_pairs['time'] = greta_latestdihedrals_gyr_pairs['time']/1000

# %%
fig, axes = plt.subplots(1,1, figsize = (15,10), sharey=True)

sns.histplot(ax=axes, data=amber_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='black')
sns.histplot(ax=axes, data=smogtogromos_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='black')
#sns.histplot(ax=axes, data=greta_ljr01_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='cyan')
#sns.histplot(ax=axes, data=greta_ljr012_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='red')
#sns.histplot(ax=axes, data=greta_newdi_harp0_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='green')
#sns.histplot(ax=axes, data=greta_newdi_harp20_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='red')
sns.histplot(ax=axes, data=greta_latestdihedrals_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='red')


fig.tight_layout()

# %%
#fig, axes = plt.subplots(1,2, figsize = (10,5), sharey=True)
#
#axes[0].set_ylabel("Gyration radious")
#axes[0].set_xlabel("Time (ns)")
#
#sns.lineplot(ax=axes[0], data=smogtogromos_gyr_pairs, y="gyr", x='time', color= '#985098', alpha=0.5)
##sns.lineplot(ax=axes[0], data=greta_gyr_pairs, y="gyr", x='time', color= '#989850', alpha=0.5)
#sns.lineplot(ax=axes[0], data=amber_gyr_pairs, y="gyr", x='time', color= '#509898', alpha=0.5)
#
#sns.histplot(ax=axes[1], data=smogtogromos_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#985098')
#sns.histplot(ax=axes[1], data=amber_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#509898')
##sns.histplot(ax=axes[1], data=greta_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#989850')
#
#fig.tight_layout()
