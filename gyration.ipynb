# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


amber_gyr_pairs = pd.read_csv('native_TTR/gyrate_amber.txt', sep = '\\s+', header=None)
amber_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
amber_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
amber_gyr_pairs['time'] = amber_gyr_pairs['time']/1000

smogtogromos_gyr_pairs = pd.read_csv('native_TTR/gyrate_smogtogromos.txt', sep = '\\s+', header=None)
smogtogromos_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
smogtogromos_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
smogtogromos_gyr_pairs['time'] = smogtogromos_gyr_pairs['time']/1000


greta_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2.txt', sep = '\\s+', header=None)
greta_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta_gyr_pairs['time'] = greta_gyr_pairs['time']/1000


greta2_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_01_nrex2.txt', sep = '\\s+', header=None)
greta2_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta2_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta2_gyr_pairs['time'] = greta2_gyr_pairs['time']/1000

greta01_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_01_nrex3.txt', sep = '\\s+', header=None)
greta01_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta01_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta01_gyr_pairs['time'] = greta01_gyr_pairs['time']/1000

greta01n_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_01_nrex3_newdih.txt', sep = '\\s+', header=None)
greta01n_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta01n_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta01n_gyr_pairs['time'] = greta01n_gyr_pairs['time']/1000


greta05_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_05_nrex3.txt', sep = '\\s+', header=None)
greta05_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta05_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta05_gyr_pairs['time'] = greta05_gyr_pairs['time']/1000

greta04_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_04_nrex3.txt', sep = '\\s+', header=None)
greta04_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta04_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta04_gyr_pairs['time'] = greta04_gyr_pairs['time']/1000

greta03_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_03_nrex3.txt', sep = '\\s+', header=None)
greta03_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta03_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta03_gyr_pairs['time'] = greta03_gyr_pairs['time']/1000

greta02_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_02_nrex3.txt', sep = '\\s+', header=None)
greta02_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta02_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta02_gyr_pairs['time'] = greta02_gyr_pairs['time']/1000

greta009_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_009_nrex3.txt', sep = '\\s+', header=None)
greta009_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta009_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta009_gyr_pairs['time'] = greta009_gyr_pairs['time']/1000

greta005_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_005_nrex3.txt', sep = '\\s+', header=None)
greta005_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta005_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta005_gyr_pairs['time'] = greta005_gyr_pairs['time']/1000

greta005n_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_005_nrex3_newdih.txt', sep = '\\s+', header=None)
greta005n_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta005n_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta005n_gyr_pairs['time'] = greta005n_gyr_pairs['time']/1000


greta001_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_001_nrex3.txt', sep = '\\s+', header=None)
greta001_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta001_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta001_gyr_pairs['time'] = greta001_gyr_pairs['time']/1000

greta0005_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_ex2_0005_nrex3.txt', sep = '\\s+', header=None)
greta0005_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta0005_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta0005_gyr_pairs['time'] = greta0005_gyr_pairs['time']/1000

greta_gyr_pairs = pd.read_csv('native_TTR/gyrate_greta_exexex01_harp0.txt', sep = '\\s+', header=None)
greta_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)
greta_gyr_pairs['time'] = greta_gyr_pairs['time']/1000

# %%
fig, axes = plt.subplots(1,1, figsize = (15,10), sharey=True)

sns.histplot(ax=axes, data=amber_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='black')
#sns.histplot(ax=axes, data=smogtogromos_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#985098')
#sns.histplot(ax=axes, data=greta_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='red')
#sns.histplot(ax=axes, data=greta2_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='green')
#sns.histplot(ax=axes, data=greta05_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='green')
#sns.histplot(ax=axes, data=greta04_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='yellow')
#sns.histplot(ax=axes, data=greta03_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='black')
#sns.histplot(ax=axes, data=greta02_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='grey')
#sns.histplot(ax=axes, data=greta01_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='cyan')
sns.histplot(ax=axes, data=greta01n_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='yellow')
sns.histplot(ax=axes, data=greta005n_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='blue')
#sns.histplot(ax=axes, data=greta009_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='black')
sns.histplot(ax=axes, data=greta005_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='cyan')
##sns.histplot(ax=axes, data=greta001_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='green')
#sns.histplot(ax=axes, data=greta0005_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='yellow')

fig.tight_layout()

# %%
fig, axes = plt.subplots(1,2, figsize = (16,8), sharey=True)

axes[0].set_ylabel("Gyration radious")
axes[0].set_xlabel("Time (ns)")

#sns.lineplot(ax=axes[0], data=smogtogromos_gyr_pairs, y="gyr", x='time', color= '#985098', alpha=0.5)
#sns.lineplot(ax=axes[0], data=greta_gyr_pairs, y="gyr", x='time', color= 'blue', alpha=0.5)
#sns.lineplot(ax=axes[0], data=greta2_gyr_pairs, y="gyr", x='time', color= 'green', alpha=0.5)
#sns.lineplot(ax=axes[0], data=greta05_gyr_pairs, y="gyr", x='time', color= 'green', alpha=0.5)
#sns.lineplot(ax=axes[0], data=greta04_gyr_pairs, y="gyr", x='time', color= 'green', alpha=0.5)
#sns.lineplot(ax=axes[0], data=greta03_gyr_pairs, y="gyr", x='time', color= 'green', alpha=0.5)
#sns.lineplot(ax=axes[0], data=greta02_gyr_pairs, y="gyr", x='time', color= 'green', alpha=0.5)
#sns.lineplot(ax=axes[0], data=greta01_gyr_pairs, y="gyr", x='time', color= 'green', alpha=0.5)
#sns.lineplot(ax=axes[0], data=amber_gyr_pairs, y="gyr", x='time', color= '#509898', alpha=0.5)

sns.histplot(ax=axes[1], data=amber_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#509898')
sns.histplot(ax=axes[1], data=smogtogromos_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#985098')
#sns.histplot(ax=axes[1], data=greta_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='blue')
#sns.histplot(ax=axes[1], data=greta2_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='green')
#sns.histplot(ax=axes[1], data=greta05_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='green')
#sns.histplot(ax=axes[1], data=greta04_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='yellow')
#sns.histplot(ax=axes[1], data=greta03_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='black')
sns.histplot(ax=axes[1], data=greta02_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='green')
sns.histplot(ax=axes[1], data=greta01_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='black')

fig.tight_layout()

# %%
fig, axes = plt.subplots(1,2, figsize = (10,5), sharey=True)

axes[0].set_ylabel("Gyration radious")
axes[0].set_xlabel("Time (ns)")

sns.lineplot(ax=axes[0], data=smogtogromos_gyr_pairs, y="gyr", x='time', color= '#985098', alpha=0.5)
#sns.lineplot(ax=axes[0], data=greta_gyr_pairs, y="gyr", x='time', color= '#989850', alpha=0.5)
sns.lineplot(ax=axes[0], data=amber_gyr_pairs, y="gyr", x='time', color= '#509898', alpha=0.5)

sns.histplot(ax=axes[1], data=smogtogromos_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#985098')
sns.histplot(ax=axes[1], data=amber_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#509898')
#sns.histplot(ax=axes[1], data=greta_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#989850')

fig.tight_layout()

# %%
import seaborn as sns

print(sns.__version__)
#sns.histplot(data=greta_gyr_pairs, x = 'gyr', color='blue', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True)
sns.histplot(data=amber_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#509898')
#sns.histplot(data=reweight_gyr_pairs, x = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True)
sns.histplot(data=smogtogromos_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#985098')
sns.histplot(data=greta_gyr_pairs, y = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True, color='#989850')
# Out:
# 0.11.0
