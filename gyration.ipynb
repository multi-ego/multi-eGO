# %%
import pandas as pd
import matplotlib.pyplot as plt

amber_gyr_pairs = pd.read_csv('native_TTR/monomer_gyration_amber.txt', sep = '\\s+', header=None)
amber_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
amber_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)


greta_gyr_pairs = pd.read_csv('native_TTR/monomer_gyration_greta.txt', sep = '\\s+', header=None)
greta_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)

reweight_gyr_pairs = pd.read_csv('native_TTR/monomer_gyration_reweight.txt', sep = '\\s+', header=None)
reweight_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
reweight_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)

reweight2_gyr_pairs = pd.read_csv('native_TTR/monomer_gyration_2reweight.txt', sep = '\\s+', header=None)
reweight2_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
reweight2_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)

#amber_gyr_pairs
#greta_gyr_pairs
#reweight_gyr_pairs
reweight2_gyr_pairs
# Out:
#             time       gyr
# 0            0.0  1.073450
# 1           50.0  1.132100
# 2          100.0  1.069080
# 3          150.0  1.093920
# 4          200.0  0.967699
# ...          ...       ...
# 29996  1499800.0  0.835069
# 29997  1499850.0  0.957109
# 29998  1499900.0  0.924290
# 29999  1499950.0  0.985112
# 30000  1500000.0  1.030700
#
# [30001 rows x 2 columns]

# %%
ax = reweight2_gyr_pairs['gyr'].plot.hist(bins=40, alpha=0.5, density=True)

# %%
ax = amber_gyr_pairs['gyr'].plot.hist(bins=40, alpha=0.5, density=True)

# %%
ax = reweight2_gyr_pairs['gyr'].plot.hist(bins=40, alpha=0.5)

# %%
import seaborn as sns

print(sns.__version__)
#sns.histplot(data=greta_gyr_pairs, x = 'gyr', color='blue', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True)
sns.histplot(data=amber_gyr_pairs, x = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True)
#sns.histplot(data=reweight_gyr_pairs, x = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True)
sns.histplot(data=reweight2_gyr_pairs, x = 'gyr', stat = 'density', binwidth = 0.02, binrange=[0.5,1.3],kde=True)
# Out:
# 0.11.0

# %%
import seaborn as sns
sns.histplot(data=amber_gyr_pairs, x = 'gyr')
