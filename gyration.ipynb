# %%
import pandas as pd
import matplotlib.pyplot as plt

amber_gyr_pairs = pd.read_csv('native_TTR/monomer_gyration_amber.txt', sep = '\\s+', header=None)
amber_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
amber_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)


greta_gyr_pairs = pd.read_csv('native_TTR/monomer_gyration_greta.txt', sep = '\\s+', header=None)
greta_gyr_pairs.columns = ['time', 'gyr', 'g', 'h', 'j']
greta_gyr_pairs.drop(['g', 'h', 'j'], axis=1, inplace = True)

print(amber_gyr_pairs)
print(greta_gyr_pairs)
# Out:
#              time       gyr
# 0             0.0  0.918466
# 1            10.0  0.938201
# 2            20.0  0.935703
# 3            30.0  0.928235
# 4            40.0  0.942187
# ...           ...       ...
# 164970  1649700.0  0.901035
# 164971  1649710.0  0.908197
# 164972  1649720.0  0.947125
# 164973  1649730.0  0.940437
# 164974  1649740.0  0.936871
#
# [164975 rows x 2 columns]
#             time       gyr
# 0            0.0  1.075510
# 1           50.0  0.915397
# 2          100.0  0.823588
# 3          150.0  1.004480
# 4          200.0  0.990136
# ...          ...       ...
# 29996  1499800.0  0.697685
# 29997  1499850.0  0.880622
# 29998  1499900.0  1.034740
# 29999  1499950.0  1.006860
# 30000  1500000.0  1.053040
#
# [30001 rows x 2 columns]

# %%
import seaborn as sns
sns.histplot(data=greta_gyr_pairs, x = 'gyr', color='blue')
sns.histplot(data=amber_gyr_pairs, x = 'gyr')

# %%
import seaborn as sns
sns.histplot(data=amber_gyr_pairs, x = 'gyr')
